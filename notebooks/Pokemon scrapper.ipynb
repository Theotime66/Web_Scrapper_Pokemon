# %% [markdown]
# # Pokemon Scrapper

# %% [markdown]
# A project to learn web scrapping

# %% [markdown]
# ## Imports and test requesting the page

# %%
import requests

URL = "https://pokemondb.net/pokedex/national"

# Send a GET request to the URL
response = requests.get(URL)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    print("Successfully fetched the page!")
    # The HTML content of the page
    html_content = response.text
    # print(html_content[:500]) # Print first 500 characters to see
else:
    print(f"Failed to fetch page. Status code: {response.status_code}")
    exit() # Exit if we couldn't get the page
# Out:
# Successfully fetched the page!

# %% [markdown]
# ## Scrapping of the page

# %% [markdown]
# ### Imports and Setup

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re # For regular expressions
from urllib.parse import urljoin # For constructing absolute URLs

BASE_URL = "https://pokemondb.net"
NATIONAL_DEX_URL = f"{BASE_URL}/pokedex/national"
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
# Be a good web citizen!
REQUEST_DELAY_SECONDS = 0.01 # Delay between requests to detail pages

# %% [markdown]
# ### Function to get all Pokémon detail page URLs and their Generations

# %%
def get_pokemon_detail_links(listing_url):
    """
    Fetches the main Pokedex listing page and extracts links to individual Pokemon
    detail pages along with their generation.
    Returns a list of dictionaries: [{'url': '...', 'generation': '...'}, ...]
    """
    pokemon_info_list = []
    print(f"Fetching listing page: {listing_url}")
    try:
        response = requests.get(listing_url, headers=HEADERS, timeout=20)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching listing page {listing_url}: {e}")
        return pokemon_info_list

    soup = BeautifulSoup(response.text, 'html.parser')
    
    main_content = soup.find('main', id='main')
    if not main_content:
        print("Warning: Could not find <main id='main'> element. Aborting link extraction.")
        return pokemon_info_list

    # Find all generation headers (e.g., <h2 id="gen-1">Generation 1 Pokémon</h2>)
    generation_headers = main_content.find_all('h2', id=re.compile(r'^gen-\d+'))
    
    processed_urls = set() # To keep track of URLs already added

    for header in generation_headers:
        generation_text = header.text.strip().replace(" Pokémon", "") # Gets "Generation X"
        print(f"Processing {generation_text}...")
        
        # The Pokémon for this generation are typically in a div immediately following the h2,
        # or the next div with class 'infocard-list'
        current_element = header.find_next_sibling()
        infocard_container = None
        
        while current_element:
            if current_element.name == 'div' and ('infocard-list' in current_element.get('class', []) or 'infocard-grid' in current_element.get('class', [])):
                infocard_container = current_element
                break
            if current_element.name == 'h2' and current_element.get('id','').startswith('gen-'): # Stop if we hit the next gen header
                break
            current_element = current_element.find_next_sibling()

        if not infocard_container:
            print(f"  Warning: Could not find infocard container for {generation_text}")
            continue

        infocards = infocard_container.find_all('div', class_='infocard')
        print(f"  Found {len(infocards)} infocards for {generation_text}.")

        for card in infocards:
            link_tag = card.select_one('span.infocard-lg-img a[href^="/pokedex/"], span.infocard-sm-img a[href^="/pokedex/"]')
            if not link_tag:
                link_tag = card.find('a', class_='ent-name', href=re.compile(r'^/pokedex/'))

            if link_tag and link_tag.has_attr('href'):
                relative_url = link_tag['href']
                if re.match(r'/pokedex/[a-zA-Z0-9-]+(?:/(?!sprites|other-forms|national).*)*$', relative_url): # More specific to avoid non-detail pages
                    absolute_url = urljoin(BASE_URL, relative_url)
                    if absolute_url not in processed_urls:
                        pokemon_info_list.append({'url': absolute_url, 'generation': generation_text})
                        processed_urls.add(absolute_url)
            # else:
            #     print(f"    Warning: Could not find a valid Pokémon link in an infocard for {generation_text}.")
            #     print(f"    Card HTML (first 100 chars): {str(card)[:100]}")


    print(f"\nExtracted info for {len(pokemon_info_list)} unique Pokémon from the listing page.")
    return pokemon_info_list

# %% [markdown]
# ### Function to scrape data from a single Pokémon detail page (Corrected version)

# %%
def scrape_pokemon_detail_page(pokemon_entry_from_list): # pokemon_entry_from_list is the dict
    """
    Fetches a Pokemon detail page and scrapes specific information.
    pokemon_entry_from_list is a dict like {'url': '...', 'generation': '...'}
    """
    # ---- START OF CRITICAL SECTION ----
    actual_url_to_fetch = pokemon_entry_from_list['url']  # Make sure you extract the URL string
    current_generation = pokemon_entry_from_list['generation'] # And the generation string
    
    # This print statement should now correctly show the generation and the URL string
    print(f"Scraping {current_generation} detail page: {actual_url_to_fetch}") 
    
    pokemon_data = {'url': actual_url_to_fetch, 'generation': current_generation, 'name': "N/A"}
    
    try:
        # Ensure requests.get() is called with the URL STRING
        response = requests.get(actual_url_to_fetch, headers=HEADERS, timeout=20) 
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        # This error print should also use the actual URL string
        print(f"  Error fetching detail page {actual_url_to_fetch}: {e}") 
        return pokemon_data 
    # ---- END OF CRITICAL SECTION ----

    soup = BeautifulSoup(response.text, 'html.parser')

    # --- Name ---
    name_element = soup.find('h1')
    pokemon_data['name'] = name_element.text.strip() if name_element else "N/A" 

    # --- Vitals Table (Type, Height, Weight, Abilities) ---
    vitals_tables = soup.find_all('table', class_='vitals-table')
    
    pokemon_data['types'] = "N/A"
    pokemon_data['weight_kg'] = None
    pokemon_data['height_m'] = None
    pokemon_data['abilities'] = "N/A"
    pokemon_data['hidden_abilities'] = "N/A"

    if not vitals_tables:
        print(f"  Warning: Could not find vitals table on {actual_url_to_fetch} for {pokemon_data.get('name')}")
    else:
        main_vitals_table = vitals_tables[0] 

        types_list = []
        type_elements = main_vitals_table.select('th:-soup-contains("Type") + td a.type-icon')
        for t_elem in type_elements:
            types_list.append(t_elem.text.strip())
        pokemon_data['types'] = ", ".join(types_list) if types_list else "N/A"
        
        for row in main_vitals_table.find_all('tr'):
            header_tag = row.find('th')
            if header_tag:
                header_text = header_tag.text.strip()
                value_tag = row.find('td')
                if value_tag:
                    value_text = value_tag.text.strip()
                    if header_text == "Weight":
                        match = re.search(r'([\d\.]+)\s*kg', value_text)
                        if match:
                            pokemon_data['weight_kg'] = float(match.group(1))
                    elif header_text == "Height":
                        match = re.search(r'([\d\.]+)\s*m', value_text)
                        if match:
                            pokemon_data['height_m'] = float(match.group(1))
        
        abilities_list = []
        hidden_abilities_list = []
        abilities_th = main_vitals_table.find(lambda tag: tag.name == 'th' and "Abilities" in tag.text)
        if abilities_th:
            abilities_td = abilities_th.find_next_sibling('td')
            if abilities_td:
                current_abilities_group = abilities_list 
                for tag_group in abilities_td.contents: 
                    if isinstance(tag_group, str) and tag_group.strip() == "": 
                        continue
                    if hasattr(tag_group, 'name') and tag_group.name == 'br': 
                        continue
                    if hasattr(tag_group, 'name') and tag_group.name == 'small' and 'hidden ability' in tag_group.text.lower():
                        current_abilities_group = hidden_abilities_list
                        continue 
                    if hasattr(tag_group, 'name') and tag_group.name in ['a', 'span']:
                        ability_name = tag_group.text.strip()
                        if ability_name: 
                            if 'hidden ability' in tag_group.get('title', '').lower() or \
                               (tag_group.find_next_sibling('small') and 'hidden ability' in tag_group.find_next_sibling('small').text.lower()):
                                if ability_name not in hidden_abilities_list:
                                    hidden_abilities_list.append(ability_name)
                            elif ability_name not in abilities_list and ability_name not in hidden_abilities_list: 
                                abilities_list.append(ability_name)
                    elif isinstance(tag_group, str) and tag_group.strip():
                        ability_name = tag_group.strip()
                        if ability_name and ability_name not in abilities_list and ability_name not in hidden_abilities_list:
                             abilities_list.append(ability_name)
        pokemon_data['abilities'] = ", ".join(list(dict.fromkeys(abilities_list))) if abilities_list else "N/A"
        pokemon_data['hidden_abilities'] = ", ".join(list(dict.fromkeys(hidden_abilities_list))) if hidden_abilities_list else "N/A"

    stat_names = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
    for stat in stat_names:
        pokemon_data[stat.replace('. ', '_').replace(' ', '_')] = None 

    stats_table = None
    for table_idx, table in enumerate(vitals_tables):
        th_texts = [th.text.strip() for th in table.select('tr > th')]
        if any(stat_name in th_texts for stat_name in ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]):
            if table.find(lambda tag: tag.name == 'th' and "Total" in tag.text.strip()):
                stats_table = table
                break
            if not stats_table and table_idx > 0 : 
                 stats_table = table 
    if stats_table:
        for row in stats_table.find_all('tr'):
            th = row.find('th')
            if th:
                stat_name_raw = th.text.strip()
                stat_name_key = stat_name_raw.replace('.', '') 
                if stat_name_key in stat_names or stat_name_raw in stat_names:
                    stat_value_td = row.find('td', class_='cell-num') 
                    if not stat_value_td: 
                        stat_value_td = row.find_all('td')[-1] 
                    if stat_value_td:
                        try:
                            df_col_name = stat_name_raw.replace('. ', '_').replace(' ', '_')
                            pokemon_data[df_col_name] = int(stat_value_td.text.strip())
                        except (ValueError, IndexError):
                            print(f"  Warning: Could not parse stat value for {stat_name_raw} for {pokemon_data['name']}")
                            pokemon_data[df_col_name] = None
    else:
        print(f"  Warning: Could not find stats table for {pokemon_data.get('name')} on {actual_url_to_fetch}")

    print(f"  Successfully scraped: {pokemon_data.get('name', 'Unknown Pokemon')} ({pokemon_data.get('generation')})")
    return pokemon_data

# %% [markdown]
# ### Main Execution Logic

# %%
if __name__ == "__main__": # For notebook execution, this part runs directly
    
    print("--- Starting Pokémon Scraping ---")
    
    # 1. Get all Pokémon detail page URLs and their generations
    pokemon_entries = get_pokemon_detail_links(NATIONAL_DEX_URL)
    
    # For testing, you might want to limit the number of pages:
    # pokemon_entries = pokemon_entries[:20] # Scrape only the first 20 Pokémon to test

    all_pokemon_data = []

    if pokemon_entries:
        print(f"\nStarting to scrape {len(pokemon_entries)} Pokémon detail pages...\n")
        
        for i, entry in enumerate(pokemon_entries): # entry is {'url': '...', 'generation': '...'}
            print(f"--- Processing Pokémon {i+1}/{len(pokemon_entries)} ---")
            data = scrape_pokemon_detail_page(entry) 
            if data:
                all_pokemon_data.append(data) # 'data' here definitely contains 'generation'
            
            time.sleep(REQUEST_DELAY_SECONDS) 
        
        print("\n--- SCRAPING COMPLETE ---")
        
        if all_pokemon_data:
            # At this point, all_pokemon_data is a list of dicts, and each dict should have a 'generation' key.
            df = pd.DataFrame(all_pokemon_data)
            
            # You can verify if 'generation' column exists here before reindexing:
            # print("\nColumns in DataFrame before reordering:", df.columns.tolist())
            # print(df[['name', 'generation']].head()) # Check if generation column has data

            stat_cols = ['HP', 'Attack', 'Defense', 'Sp_Atk', 'Sp_Def', 'Speed']
            
            # !!! CRITICAL LINE: Ensure 'generation' is in this list EXACTLY as 'generation' !!!
            ordered_cols = ['name', 'generation', 'types', 'weight_kg', 'height_m', 
                           'abilities', 'hidden_abilities'] + stat_cols + ['url']
            
            # This reindex operation uses the ordered_cols list. If 'generation' isn't in it, it gets dropped.
            df = df.reindex(columns=ordered_cols)

            # You can verify columns again after reindexing:
            # print("\nColumns in DataFrame AFTER reordering:", df.columns.tolist())
            # print(df[['name', 'generation']].head()) # Check again

            csv_filename = 'pokemon_pokedex_data_with_generations.csv'
            df.to_csv(csv_filename, index=False, encoding='utf-8-sig')
            print(f"\nData for {len(all_pokemon_data)} Pokémon saved to {csv_filename}")
            
            print("\nFirst 5 entries from CSV (will be read back to verify):")
            try:
                df_read_test = pd.read_csv(csv_filename)
                print(df_read_test.head())
                if 'generation' not in df_read_test.columns:
                    print("WARNING: 'generation' column is NOT in the saved CSV file according to read_csv.")
                else:
                    print("'generation' column IS in the saved CSV file.")
            except Exception as e:
                print(f"Error reading back CSV for verification: {e}")
            
        else:
            print("No data was scraped.")
            
    else:
        print("No detail links found from the main Pokedex page. Exiting.")
# Out:
# --- Starting Pokémon Scraping ---
# Fetching listing page: https://pokemondb.net/pokedex/national
# Processing Generation 1...
#   Found 151 infocards for Generation 1.
# Processing Generation 2...
#   Found 100 infocards for Generation 2.
# Processing Generation 3...
#   Found 135 infocards for Generation 3.
# Processing Generation 4...
#   Found 107 infocards for Generation 4.
# Processing Generation 5...
#   Found 156 infocards for Generation 5.
# Processing Generation 6...
#   Found 72 infocards for Generation 6.
# Processing Generation 7...
#   Found 88 infocards for Generation 7.
# Processing Generation 8...
#   Found 96 infocards for Generation 8.
# Processing Generation 9...
#   Found 120 infocards for Generation 9.
#
# Extracted info for 1025 unique Pokémon from the listing page.
#
# Starting to scrape 1025 Pokémon detail pages...
#
# --- Processing Pokémon 1/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/bulbasaur
#   Successfully scraped: Bulbasaur (Generation 1)
# --- Processing Pokémon 2/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/ivysaur
#   Successfully scraped: Ivysaur (Generation 1)
# --- Processing Pokémon 3/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/venusaur
#   Successfully scraped: Venusaur (Generation 1)
# --- Processing Pokémon 4/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/charmander
#   Successfully scraped: Charmander (Generation 1)
# --- Processing Pokémon 5/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/charmeleon
#   Successfully scraped: Charmeleon (Generation 1)
# --- Processing Pokémon 6/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/charizard
#   Successfully scraped: Charizard (Generation 1)
# --- Processing Pokémon 7/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/squirtle
#   Successfully scraped: Squirtle (Generation 1)
# --- Processing Pokémon 8/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/wartortle
#   Successfully scraped: Wartortle (Generation 1)
# --- Processing Pokémon 9/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/blastoise
#   Successfully scraped: Blastoise (Generation 1)
# --- Processing Pokémon 10/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/caterpie
#   Successfully scraped: Caterpie (Generation 1)
# --- Processing Pokémon 11/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/metapod
#   Successfully scraped: Metapod (Generation 1)
# --- Processing Pokémon 12/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/butterfree
#   Successfully scraped: Butterfree (Generation 1)
# --- Processing Pokémon 13/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/weedle
#   Successfully scraped: Weedle (Generation 1)
# --- Processing Pokémon 14/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/kakuna
#   Successfully scraped: Kakuna (Generation 1)
# --- Processing Pokémon 15/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/beedrill
#   Successfully scraped: Beedrill (Generation 1)
# --- Processing Pokémon 16/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/pidgey
#   Successfully scraped: Pidgey (Generation 1)
# --- Processing Pokémon 17/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/pidgeotto
#   Successfully scraped: Pidgeotto (Generation 1)
# --- Processing Pokémon 18/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/pidgeot
#   Successfully scraped: Pidgeot (Generation 1)
# --- Processing Pokémon 19/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/rattata
#   Successfully scraped: Rattata (Generation 1)
# --- Processing Pokémon 20/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/raticate
#   Successfully scraped: Raticate (Generation 1)
# --- Processing Pokémon 21/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/spearow
#   Successfully scraped: Spearow (Generation 1)
# --- Processing Pokémon 22/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/fearow
#   Successfully scraped: Fearow (Generation 1)
# --- Processing Pokémon 23/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/ekans
#   Successfully scraped: Ekans (Generation 1)
# --- Processing Pokémon 24/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/arbok
#   Successfully scraped: Arbok (Generation 1)
# --- Processing Pokémon 25/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/pikachu
#   Successfully scraped: Pikachu (Generation 1)
# --- Processing Pokémon 26/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/raichu
#   Successfully scraped: Raichu (Generation 1)
# --- Processing Pokémon 27/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/sandshrew
#   Successfully scraped: Sandshrew (Generation 1)
# --- Processing Pokémon 28/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/sandslash
#   Successfully scraped: Sandslash (Generation 1)
# --- Processing Pokémon 29/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/nidoran-f
#   Successfully scraped: Nidoran♀ (female) (Generation 1)
# --- Processing Pokémon 30/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/nidorina
#   Successfully scraped: Nidorina (Generation 1)
# --- Processing Pokémon 31/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/nidoqueen
#   Successfully scraped: Nidoqueen (Generation 1)
# --- Processing Pokémon 32/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/nidoran-m
#   Successfully scraped: Nidoran♂ (male) (Generation 1)
# --- Processing Pokémon 33/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/nidorino
#   Successfully scraped: Nidorino (Generation 1)
# --- Processing Pokémon 34/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/nidoking
#   Successfully scraped: Nidoking (Generation 1)
# --- Processing Pokémon 35/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/clefairy
#   Successfully scraped: Clefairy (Generation 1)
# --- Processing Pokémon 36/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/clefable
#   Successfully scraped: Clefable (Generation 1)
# --- Processing Pokémon 37/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/vulpix
#   Successfully scraped: Vulpix (Generation 1)
# --- Processing Pokémon 38/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/ninetales
#   Successfully scraped: Ninetales (Generation 1)
# --- Processing Pokémon 39/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/jigglypuff
#   Successfully scraped: Jigglypuff (Generation 1)
# --- Processing Pokémon 40/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/wigglytuff
#   Successfully scraped: Wigglytuff (Generation 1)
# --- Processing Pokémon 41/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/zubat
#   Successfully scraped: Zubat (Generation 1)
# --- Processing Pokémon 42/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/golbat
#   Successfully scraped: Golbat (Generation 1)
# --- Processing Pokémon 43/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/oddish
#   Successfully scraped: Oddish (Generation 1)
# --- Processing Pokémon 44/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/gloom
#   Successfully scraped: Gloom (Generation 1)
# --- Processing Pokémon 45/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/vileplume
#   Successfully scraped: Vileplume (Generation 1)
# --- Processing Pokémon 46/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/paras
#   Successfully scraped: Paras (Generation 1)
# --- Processing Pokémon 47/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/parasect
#   Successfully scraped: Parasect (Generation 1)
# --- Processing Pokémon 48/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/venonat
#   Successfully scraped: Venonat (Generation 1)
# --- Processing Pokémon 49/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/venomoth
#   Successfully scraped: Venomoth (Generation 1)
# --- Processing Pokémon 50/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/diglett
#   Successfully scraped: Diglett (Generation 1)
# --- Processing Pokémon 51/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/dugtrio
#   Successfully scraped: Dugtrio (Generation 1)
# --- Processing Pokémon 52/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/meowth
#   Successfully scraped: Meowth (Generation 1)
# --- Processing Pokémon 53/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/persian
#   Successfully scraped: Persian (Generation 1)
# --- Processing Pokémon 54/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/psyduck
#   Successfully scraped: Psyduck (Generation 1)
# --- Processing Pokémon 55/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/golduck
#   Successfully scraped: Golduck (Generation 1)
# --- Processing Pokémon 56/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/mankey
#   Successfully scraped: Mankey (Generation 1)
# --- Processing Pokémon 57/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/primeape
#   Successfully scraped: Primeape (Generation 1)
# --- Processing Pokémon 58/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/growlithe
#   Successfully scraped: Growlithe (Generation 1)
# --- Processing Pokémon 59/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/arcanine
#   Successfully scraped: Arcanine (Generation 1)
# --- Processing Pokémon 60/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/poliwag
#   Successfully scraped: Poliwag (Generation 1)
# --- Processing Pokémon 61/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/poliwhirl
#   Successfully scraped: Poliwhirl (Generation 1)
# --- Processing Pokémon 62/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/poliwrath
#   Successfully scraped: Poliwrath (Generation 1)
# --- Processing Pokémon 63/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/abra
#   Successfully scraped: Abra (Generation 1)
# --- Processing Pokémon 64/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/kadabra
#   Successfully scraped: Kadabra (Generation 1)
# --- Processing Pokémon 65/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/alakazam
#   Successfully scraped: Alakazam (Generation 1)
# --- Processing Pokémon 66/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/machop
#   Successfully scraped: Machop (Generation 1)
# --- Processing Pokémon 67/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/machoke
#   Successfully scraped: Machoke (Generation 1)
# --- Processing Pokémon 68/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/machamp
#   Successfully scraped: Machamp (Generation 1)
# --- Processing Pokémon 69/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/bellsprout
#   Successfully scraped: Bellsprout (Generation 1)
# --- Processing Pokémon 70/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/weepinbell
#   Successfully scraped: Weepinbell (Generation 1)
# --- Processing Pokémon 71/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/victreebel
#   Successfully scraped: Victreebel (Generation 1)
# --- Processing Pokémon 72/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/tentacool
#   Successfully scraped: Tentacool (Generation 1)
# --- Processing Pokémon 73/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/tentacruel
#   Successfully scraped: Tentacruel (Generation 1)
# --- Processing Pokémon 74/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/geodude
#   Successfully scraped: Geodude (Generation 1)
# --- Processing Pokémon 75/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/graveler
#   Successfully scraped: Graveler (Generation 1)
# --- Processing Pokémon 76/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/golem
#   Successfully scraped: Golem (Generation 1)
# --- Processing Pokémon 77/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/ponyta
#   Successfully scraped: Ponyta (Generation 1)
# --- Processing Pokémon 78/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/rapidash
#   Successfully scraped: Rapidash (Generation 1)
# --- Processing Pokémon 79/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/slowpoke
#   Successfully scraped: Slowpoke (Generation 1)
# --- Processing Pokémon 80/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/slowbro
#   Successfully scraped: Slowbro (Generation 1)
# --- Processing Pokémon 81/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/magnemite
#   Successfully scraped: Magnemite (Generation 1)
# --- Processing Pokémon 82/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/magneton
#   Successfully scraped: Magneton (Generation 1)
# --- Processing Pokémon 83/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/farfetchd
#   Successfully scraped: Farfetch'd (Generation 1)
# --- Processing Pokémon 84/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/doduo
#   Successfully scraped: Doduo (Generation 1)
# --- Processing Pokémon 85/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/dodrio
#   Successfully scraped: Dodrio (Generation 1)
# --- Processing Pokémon 86/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/seel
#   Successfully scraped: Seel (Generation 1)
# --- Processing Pokémon 87/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/dewgong
#   Successfully scraped: Dewgong (Generation 1)
# --- Processing Pokémon 88/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/grimer
#   Successfully scraped: Grimer (Generation 1)
# --- Processing Pokémon 89/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/muk
#   Successfully scraped: Muk (Generation 1)
# --- Processing Pokémon 90/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/shellder
#   Successfully scraped: Shellder (Generation 1)
# --- Processing Pokémon 91/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/cloyster
#   Successfully scraped: Cloyster (Generation 1)
# --- Processing Pokémon 92/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/gastly
#   Successfully scraped: Gastly (Generation 1)
# --- Processing Pokémon 93/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/haunter
#   Successfully scraped: Haunter (Generation 1)
# --- Processing Pokémon 94/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/gengar
#   Successfully scraped: Gengar (Generation 1)
# --- Processing Pokémon 95/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/onix
#   Successfully scraped: Onix (Generation 1)
# --- Processing Pokémon 96/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/drowzee
#   Successfully scraped: Drowzee (Generation 1)
# --- Processing Pokémon 97/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/hypno
#   Successfully scraped: Hypno (Generation 1)
# --- Processing Pokémon 98/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/krabby
#   Successfully scraped: Krabby (Generation 1)
# --- Processing Pokémon 99/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/kingler
#   Successfully scraped: Kingler (Generation 1)
# --- Processing Pokémon 100/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/voltorb
#   Successfully scraped: Voltorb (Generation 1)
# --- Processing Pokémon 101/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/electrode
#   Successfully scraped: Electrode (Generation 1)
# --- Processing Pokémon 102/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/exeggcute
#   Successfully scraped: Exeggcute (Generation 1)
# --- Processing Pokémon 103/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/exeggutor
#   Successfully scraped: Exeggutor (Generation 1)
# --- Processing Pokémon 104/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/cubone
#   Successfully scraped: Cubone (Generation 1)
# --- Processing Pokémon 105/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/marowak
#   Successfully scraped: Marowak (Generation 1)
# --- Processing Pokémon 106/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/hitmonlee
#   Successfully scraped: Hitmonlee (Generation 1)
# --- Processing Pokémon 107/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/hitmonchan
#   Successfully scraped: Hitmonchan (Generation 1)
# --- Processing Pokémon 108/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/lickitung
#   Successfully scraped: Lickitung (Generation 1)
# --- Processing Pokémon 109/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/koffing
#   Successfully scraped: Koffing (Generation 1)
# --- Processing Pokémon 110/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/weezing
#   Successfully scraped: Weezing (Generation 1)
# --- Processing Pokémon 111/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/rhyhorn
#   Successfully scraped: Rhyhorn (Generation 1)
# --- Processing Pokémon 112/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/rhydon
#   Successfully scraped: Rhydon (Generation 1)
# --- Processing Pokémon 113/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/chansey
#   Successfully scraped: Chansey (Generation 1)
# --- Processing Pokémon 114/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/tangela
#   Successfully scraped: Tangela (Generation 1)
# --- Processing Pokémon 115/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/kangaskhan
#   Successfully scraped: Kangaskhan (Generation 1)
# --- Processing Pokémon 116/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/horsea
#   Successfully scraped: Horsea (Generation 1)
# --- Processing Pokémon 117/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/seadra
#   Successfully scraped: Seadra (Generation 1)
# --- Processing Pokémon 118/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/goldeen
#   Successfully scraped: Goldeen (Generation 1)
# --- Processing Pokémon 119/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/seaking
#   Successfully scraped: Seaking (Generation 1)
# --- Processing Pokémon 120/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/staryu
#   Successfully scraped: Staryu (Generation 1)
# --- Processing Pokémon 121/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/starmie
#   Successfully scraped: Starmie (Generation 1)
# --- Processing Pokémon 122/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/mr-mime
#   Successfully scraped: Mr. Mime (Generation 1)
# --- Processing Pokémon 123/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/scyther
#   Successfully scraped: Scyther (Generation 1)
# --- Processing Pokémon 124/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/jynx
#   Successfully scraped: Jynx (Generation 1)
# --- Processing Pokémon 125/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/electabuzz
#   Successfully scraped: Electabuzz (Generation 1)
# --- Processing Pokémon 126/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/magmar
#   Successfully scraped: Magmar (Generation 1)
# --- Processing Pokémon 127/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/pinsir
#   Successfully scraped: Pinsir (Generation 1)
# --- Processing Pokémon 128/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/tauros
#   Successfully scraped: Tauros (Generation 1)
# --- Processing Pokémon 129/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/magikarp
#   Successfully scraped: Magikarp (Generation 1)
# --- Processing Pokémon 130/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/gyarados
#   Successfully scraped: Gyarados (Generation 1)
# --- Processing Pokémon 131/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/lapras
#   Successfully scraped: Lapras (Generation 1)
# --- Processing Pokémon 132/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/ditto
#   Successfully scraped: Ditto (Generation 1)
# --- Processing Pokémon 133/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/eevee
#   Successfully scraped: Eevee (Generation 1)
# --- Processing Pokémon 134/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/vaporeon
#   Successfully scraped: Vaporeon (Generation 1)
# --- Processing Pokémon 135/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/jolteon
#   Successfully scraped: Jolteon (Generation 1)
# --- Processing Pokémon 136/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/flareon
#   Successfully scraped: Flareon (Generation 1)
# --- Processing Pokémon 137/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/porygon
#   Successfully scraped: Porygon (Generation 1)
# --- Processing Pokémon 138/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/omanyte
#   Successfully scraped: Omanyte (Generation 1)
# --- Processing Pokémon 139/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/omastar
#   Successfully scraped: Omastar (Generation 1)
# --- Processing Pokémon 140/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/kabuto
#   Successfully scraped: Kabuto (Generation 1)
# --- Processing Pokémon 141/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/kabutops
#   Successfully scraped: Kabutops (Generation 1)
# --- Processing Pokémon 142/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/aerodactyl
#   Successfully scraped: Aerodactyl (Generation 1)
# --- Processing Pokémon 143/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/snorlax
#   Successfully scraped: Snorlax (Generation 1)
# --- Processing Pokémon 144/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/articuno
#   Successfully scraped: Articuno (Generation 1)
# --- Processing Pokémon 145/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/zapdos
#   Successfully scraped: Zapdos (Generation 1)
# --- Processing Pokémon 146/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/moltres
#   Successfully scraped: Moltres (Generation 1)
# --- Processing Pokémon 147/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/dratini
#   Successfully scraped: Dratini (Generation 1)
# --- Processing Pokémon 148/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/dragonair
#   Successfully scraped: Dragonair (Generation 1)
# --- Processing Pokémon 149/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/dragonite
#   Successfully scraped: Dragonite (Generation 1)
# --- Processing Pokémon 150/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/mewtwo
#   Successfully scraped: Mewtwo (Generation 1)
# --- Processing Pokémon 151/1025 ---
# Scraping Generation 1 detail page: https://pokemondb.net/pokedex/mew
#   Successfully scraped: Mew (Generation 1)
# --- Processing Pokémon 152/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/chikorita
#   Successfully scraped: Chikorita (Generation 2)
# --- Processing Pokémon 153/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/bayleef
#   Successfully scraped: Bayleef (Generation 2)
# --- Processing Pokémon 154/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/meganium
#   Successfully scraped: Meganium (Generation 2)
# --- Processing Pokémon 155/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/cyndaquil
#   Successfully scraped: Cyndaquil (Generation 2)
# --- Processing Pokémon 156/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/quilava
#   Successfully scraped: Quilava (Generation 2)
# --- Processing Pokémon 157/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/typhlosion
#   Successfully scraped: Typhlosion (Generation 2)
# --- Processing Pokémon 158/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/totodile
#   Successfully scraped: Totodile (Generation 2)
# --- Processing Pokémon 159/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/croconaw
#   Successfully scraped: Croconaw (Generation 2)
# --- Processing Pokémon 160/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/feraligatr
#   Successfully scraped: Feraligatr (Generation 2)
# --- Processing Pokémon 161/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/sentret
#   Successfully scraped: Sentret (Generation 2)
# --- Processing Pokémon 162/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/furret
#   Successfully scraped: Furret (Generation 2)
# --- Processing Pokémon 163/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/hoothoot
#   Successfully scraped: Hoothoot (Generation 2)
# --- Processing Pokémon 164/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/noctowl
#   Successfully scraped: Noctowl (Generation 2)
# --- Processing Pokémon 165/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/ledyba
#   Successfully scraped: Ledyba (Generation 2)
# --- Processing Pokémon 166/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/ledian
#   Successfully scraped: Ledian (Generation 2)
# --- Processing Pokémon 167/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/spinarak
#   Successfully scraped: Spinarak (Generation 2)
# --- Processing Pokémon 168/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/ariados
#   Successfully scraped: Ariados (Generation 2)
# --- Processing Pokémon 169/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/crobat
#   Successfully scraped: Crobat (Generation 2)
# --- Processing Pokémon 170/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/chinchou
#   Successfully scraped: Chinchou (Generation 2)
# --- Processing Pokémon 171/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/lanturn
#   Successfully scraped: Lanturn (Generation 2)
# --- Processing Pokémon 172/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/pichu
#   Successfully scraped: Pichu (Generation 2)
# --- Processing Pokémon 173/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/cleffa
#   Successfully scraped: Cleffa (Generation 2)
# --- Processing Pokémon 174/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/igglybuff
#   Successfully scraped: Igglybuff (Generation 2)
# --- Processing Pokémon 175/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/togepi
#   Successfully scraped: Togepi (Generation 2)
# --- Processing Pokémon 176/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/togetic
#   Successfully scraped: Togetic (Generation 2)
# --- Processing Pokémon 177/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/natu
#   Successfully scraped: Natu (Generation 2)
# --- Processing Pokémon 178/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/xatu
#   Successfully scraped: Xatu (Generation 2)
# --- Processing Pokémon 179/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/mareep
#   Successfully scraped: Mareep (Generation 2)
# --- Processing Pokémon 180/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/flaaffy
#   Successfully scraped: Flaaffy (Generation 2)
# --- Processing Pokémon 181/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/ampharos
#   Successfully scraped: Ampharos (Generation 2)
# --- Processing Pokémon 182/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/bellossom
#   Successfully scraped: Bellossom (Generation 2)
# --- Processing Pokémon 183/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/marill
#   Successfully scraped: Marill (Generation 2)
# --- Processing Pokémon 184/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/azumarill
#   Successfully scraped: Azumarill (Generation 2)
# --- Processing Pokémon 185/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/sudowoodo
#   Successfully scraped: Sudowoodo (Generation 2)
# --- Processing Pokémon 186/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/politoed
#   Successfully scraped: Politoed (Generation 2)
# --- Processing Pokémon 187/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/hoppip
#   Successfully scraped: Hoppip (Generation 2)
# --- Processing Pokémon 188/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/skiploom
#   Successfully scraped: Skiploom (Generation 2)
# --- Processing Pokémon 189/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/jumpluff
#   Successfully scraped: Jumpluff (Generation 2)
# --- Processing Pokémon 190/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/aipom
#   Successfully scraped: Aipom (Generation 2)
# --- Processing Pokémon 191/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/sunkern
#   Successfully scraped: Sunkern (Generation 2)
# --- Processing Pokémon 192/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/sunflora
#   Successfully scraped: Sunflora (Generation 2)
# --- Processing Pokémon 193/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/yanma
#   Successfully scraped: Yanma (Generation 2)
# --- Processing Pokémon 194/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/wooper
#   Successfully scraped: Wooper (Generation 2)
# --- Processing Pokémon 195/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/quagsire
#   Successfully scraped: Quagsire (Generation 2)
# --- Processing Pokémon 196/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/espeon
#   Successfully scraped: Espeon (Generation 2)
# --- Processing Pokémon 197/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/umbreon
#   Successfully scraped: Umbreon (Generation 2)
# --- Processing Pokémon 198/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/murkrow
#   Successfully scraped: Murkrow (Generation 2)
# --- Processing Pokémon 199/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/slowking
#   Successfully scraped: Slowking (Generation 2)
# --- Processing Pokémon 200/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/misdreavus
#   Successfully scraped: Misdreavus (Generation 2)
# --- Processing Pokémon 201/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/unown
#   Successfully scraped: Unown (Generation 2)
# --- Processing Pokémon 202/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/wobbuffet
#   Successfully scraped: Wobbuffet (Generation 2)
# --- Processing Pokémon 203/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/girafarig
#   Successfully scraped: Girafarig (Generation 2)
# --- Processing Pokémon 204/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/pineco
#   Successfully scraped: Pineco (Generation 2)
# --- Processing Pokémon 205/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/forretress
#   Successfully scraped: Forretress (Generation 2)
# --- Processing Pokémon 206/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/dunsparce
#   Successfully scraped: Dunsparce (Generation 2)
# --- Processing Pokémon 207/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/gligar
#   Successfully scraped: Gligar (Generation 2)
# --- Processing Pokémon 208/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/steelix
#   Successfully scraped: Steelix (Generation 2)
# --- Processing Pokémon 209/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/snubbull
#   Successfully scraped: Snubbull (Generation 2)
# --- Processing Pokémon 210/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/granbull
#   Successfully scraped: Granbull (Generation 2)
# --- Processing Pokémon 211/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/qwilfish
#   Successfully scraped: Qwilfish (Generation 2)
# --- Processing Pokémon 212/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/scizor
#   Successfully scraped: Scizor (Generation 2)
# --- Processing Pokémon 213/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/shuckle
#   Successfully scraped: Shuckle (Generation 2)
# --- Processing Pokémon 214/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/heracross
#   Successfully scraped: Heracross (Generation 2)
# --- Processing Pokémon 215/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/sneasel
#   Successfully scraped: Sneasel (Generation 2)
# --- Processing Pokémon 216/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/teddiursa
#   Successfully scraped: Teddiursa (Generation 2)
# --- Processing Pokémon 217/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/ursaring
#   Successfully scraped: Ursaring (Generation 2)
# --- Processing Pokémon 218/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/slugma
#   Successfully scraped: Slugma (Generation 2)
# --- Processing Pokémon 219/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/magcargo
#   Successfully scraped: Magcargo (Generation 2)
# --- Processing Pokémon 220/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/swinub
#   Successfully scraped: Swinub (Generation 2)
# --- Processing Pokémon 221/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/piloswine
#   Successfully scraped: Piloswine (Generation 2)
# --- Processing Pokémon 222/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/corsola
#   Successfully scraped: Corsola (Generation 2)
# --- Processing Pokémon 223/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/remoraid
#   Successfully scraped: Remoraid (Generation 2)
# --- Processing Pokémon 224/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/octillery
#   Successfully scraped: Octillery (Generation 2)
# --- Processing Pokémon 225/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/delibird
#   Successfully scraped: Delibird (Generation 2)
# --- Processing Pokémon 226/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/mantine
#   Successfully scraped: Mantine (Generation 2)
# --- Processing Pokémon 227/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/skarmory
#   Successfully scraped: Skarmory (Generation 2)
# --- Processing Pokémon 228/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/houndour
#   Successfully scraped: Houndour (Generation 2)
# --- Processing Pokémon 229/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/houndoom
#   Successfully scraped: Houndoom (Generation 2)
# --- Processing Pokémon 230/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/kingdra
#   Successfully scraped: Kingdra (Generation 2)
# --- Processing Pokémon 231/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/phanpy
#   Successfully scraped: Phanpy (Generation 2)
# --- Processing Pokémon 232/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/donphan
#   Successfully scraped: Donphan (Generation 2)
# --- Processing Pokémon 233/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/porygon2
#   Successfully scraped: Porygon2 (Generation 2)
# --- Processing Pokémon 234/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/stantler
#   Successfully scraped: Stantler (Generation 2)
# --- Processing Pokémon 235/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/smeargle
#   Successfully scraped: Smeargle (Generation 2)
# --- Processing Pokémon 236/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/tyrogue
#   Successfully scraped: Tyrogue (Generation 2)
# --- Processing Pokémon 237/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/hitmontop
#   Successfully scraped: Hitmontop (Generation 2)
# --- Processing Pokémon 238/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/smoochum
#   Successfully scraped: Smoochum (Generation 2)
# --- Processing Pokémon 239/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/elekid
#   Successfully scraped: Elekid (Generation 2)
# --- Processing Pokémon 240/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/magby
#   Successfully scraped: Magby (Generation 2)
# --- Processing Pokémon 241/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/miltank
#   Successfully scraped: Miltank (Generation 2)
# --- Processing Pokémon 242/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/blissey
#   Successfully scraped: Blissey (Generation 2)
# --- Processing Pokémon 243/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/raikou
#   Successfully scraped: Raikou (Generation 2)
# --- Processing Pokémon 244/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/entei
#   Successfully scraped: Entei (Generation 2)
# --- Processing Pokémon 245/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/suicune
#   Successfully scraped: Suicune (Generation 2)
# --- Processing Pokémon 246/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/larvitar
#   Successfully scraped: Larvitar (Generation 2)
# --- Processing Pokémon 247/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/pupitar
#   Successfully scraped: Pupitar (Generation 2)
# --- Processing Pokémon 248/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/tyranitar
#   Successfully scraped: Tyranitar (Generation 2)
# --- Processing Pokémon 249/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/lugia
#   Successfully scraped: Lugia (Generation 2)
# --- Processing Pokémon 250/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/ho-oh
#   Successfully scraped: Ho-oh (Generation 2)
# --- Processing Pokémon 251/1025 ---
# Scraping Generation 2 detail page: https://pokemondb.net/pokedex/celebi
#   Successfully scraped: Celebi (Generation 2)
# --- Processing Pokémon 252/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/treecko
#   Successfully scraped: Treecko (Generation 3)
# --- Processing Pokémon 253/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/grovyle
#   Successfully scraped: Grovyle (Generation 3)
# --- Processing Pokémon 254/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/sceptile
#   Successfully scraped: Sceptile (Generation 3)
# --- Processing Pokémon 255/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/torchic
#   Successfully scraped: Torchic (Generation 3)
# --- Processing Pokémon 256/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/combusken
#   Successfully scraped: Combusken (Generation 3)
# --- Processing Pokémon 257/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/blaziken
#   Successfully scraped: Blaziken (Generation 3)
# --- Processing Pokémon 258/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/mudkip
#   Successfully scraped: Mudkip (Generation 3)
# --- Processing Pokémon 259/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/marshtomp
#   Successfully scraped: Marshtomp (Generation 3)
# --- Processing Pokémon 260/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/swampert
#   Successfully scraped: Swampert (Generation 3)
# --- Processing Pokémon 261/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/poochyena
#   Successfully scraped: Poochyena (Generation 3)
# --- Processing Pokémon 262/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/mightyena
#   Successfully scraped: Mightyena (Generation 3)
# --- Processing Pokémon 263/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/zigzagoon
#   Successfully scraped: Zigzagoon (Generation 3)
# --- Processing Pokémon 264/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/linoone
#   Successfully scraped: Linoone (Generation 3)
# --- Processing Pokémon 265/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/wurmple
#   Successfully scraped: Wurmple (Generation 3)
# --- Processing Pokémon 266/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/silcoon
#   Successfully scraped: Silcoon (Generation 3)
# --- Processing Pokémon 267/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/beautifly
#   Successfully scraped: Beautifly (Generation 3)
# --- Processing Pokémon 268/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/cascoon
#   Successfully scraped: Cascoon (Generation 3)
# --- Processing Pokémon 269/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/dustox
#   Successfully scraped: Dustox (Generation 3)
# --- Processing Pokémon 270/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/lotad
#   Successfully scraped: Lotad (Generation 3)
# --- Processing Pokémon 271/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/lombre
#   Successfully scraped: Lombre (Generation 3)
# --- Processing Pokémon 272/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/ludicolo
#   Successfully scraped: Ludicolo (Generation 3)
# --- Processing Pokémon 273/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/seedot
#   Successfully scraped: Seedot (Generation 3)
# --- Processing Pokémon 274/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/nuzleaf
#   Successfully scraped: Nuzleaf (Generation 3)
# --- Processing Pokémon 275/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/shiftry
#   Successfully scraped: Shiftry (Generation 3)
# --- Processing Pokémon 276/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/taillow
#   Successfully scraped: Taillow (Generation 3)
# --- Processing Pokémon 277/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/swellow
#   Successfully scraped: Swellow (Generation 3)
# --- Processing Pokémon 278/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/wingull
#   Successfully scraped: Wingull (Generation 3)
# --- Processing Pokémon 279/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/pelipper
#   Successfully scraped: Pelipper (Generation 3)
# --- Processing Pokémon 280/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/ralts
#   Successfully scraped: Ralts (Generation 3)
# --- Processing Pokémon 281/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/kirlia
#   Successfully scraped: Kirlia (Generation 3)
# --- Processing Pokémon 282/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/gardevoir
#   Successfully scraped: Gardevoir (Generation 3)
# --- Processing Pokémon 283/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/surskit
#   Successfully scraped: Surskit (Generation 3)
# --- Processing Pokémon 284/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/masquerain
#   Successfully scraped: Masquerain (Generation 3)
# --- Processing Pokémon 285/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/shroomish
#   Successfully scraped: Shroomish (Generation 3)
# --- Processing Pokémon 286/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/breloom
#   Successfully scraped: Breloom (Generation 3)
# --- Processing Pokémon 287/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/slakoth
#   Successfully scraped: Slakoth (Generation 3)
# --- Processing Pokémon 288/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/vigoroth
#   Successfully scraped: Vigoroth (Generation 3)
# --- Processing Pokémon 289/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/slaking
#   Successfully scraped: Slaking (Generation 3)
# --- Processing Pokémon 290/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/nincada
#   Successfully scraped: Nincada (Generation 3)
# --- Processing Pokémon 291/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/ninjask
#   Successfully scraped: Ninjask (Generation 3)
# --- Processing Pokémon 292/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/shedinja
#   Successfully scraped: Shedinja (Generation 3)
# --- Processing Pokémon 293/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/whismur
#   Successfully scraped: Whismur (Generation 3)
# --- Processing Pokémon 294/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/loudred
#   Successfully scraped: Loudred (Generation 3)
# --- Processing Pokémon 295/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/exploud
#   Successfully scraped: Exploud (Generation 3)
# --- Processing Pokémon 296/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/makuhita
#   Successfully scraped: Makuhita (Generation 3)
# --- Processing Pokémon 297/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/hariyama
#   Successfully scraped: Hariyama (Generation 3)
# --- Processing Pokémon 298/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/azurill
#   Successfully scraped: Azurill (Generation 3)
# --- Processing Pokémon 299/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/nosepass
#   Successfully scraped: Nosepass (Generation 3)
# --- Processing Pokémon 300/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/skitty
#   Successfully scraped: Skitty (Generation 3)
# --- Processing Pokémon 301/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/delcatty
#   Successfully scraped: Delcatty (Generation 3)
# --- Processing Pokémon 302/1025 ---
# Scraping Generation 3 detail page: https://pokemondb.net/pokedex/sableye
# ...
#   Successfully scraped: Garganacl (Generation 9)
# --- Processing Pokémon 935/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/charcadet
#   Successfully scraped: Charcadet (Generation 9)
# --- Processing Pokémon 936/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/armarouge
#   Successfully scraped: Armarouge (Generation 9)
# --- Processing Pokémon 937/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/ceruledge
#   Successfully scraped: Ceruledge (Generation 9)
# --- Processing Pokémon 938/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/tadbulb
#   Successfully scraped: Tadbulb (Generation 9)
# --- Processing Pokémon 939/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/bellibolt
#   Successfully scraped: Bellibolt (Generation 9)
# --- Processing Pokémon 940/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/wattrel
#   Successfully scraped: Wattrel (Generation 9)
# --- Processing Pokémon 941/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/kilowattrel
#   Successfully scraped: Kilowattrel (Generation 9)
# --- Processing Pokémon 942/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/maschiff
#   Successfully scraped: Maschiff (Generation 9)
# --- Processing Pokémon 943/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/mabosstiff
#   Successfully scraped: Mabosstiff (Generation 9)
# --- Processing Pokémon 944/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/shroodle
#   Successfully scraped: Shroodle (Generation 9)
# --- Processing Pokémon 945/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/grafaiai
#   Successfully scraped: Grafaiai (Generation 9)
# --- Processing Pokémon 946/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/bramblin
#   Successfully scraped: Bramblin (Generation 9)
# --- Processing Pokémon 947/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/brambleghast
#   Successfully scraped: Brambleghast (Generation 9)
# --- Processing Pokémon 948/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/toedscool
#   Successfully scraped: Toedscool (Generation 9)
# --- Processing Pokémon 949/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/toedscruel
#   Successfully scraped: Toedscruel (Generation 9)
# --- Processing Pokémon 950/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/klawf
#   Successfully scraped: Klawf (Generation 9)
# --- Processing Pokémon 951/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/capsakid
#   Successfully scraped: Capsakid (Generation 9)
# --- Processing Pokémon 952/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/scovillain
#   Successfully scraped: Scovillain (Generation 9)
# --- Processing Pokémon 953/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/rellor
#   Successfully scraped: Rellor (Generation 9)
# --- Processing Pokémon 954/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/rabsca
#   Successfully scraped: Rabsca (Generation 9)
# --- Processing Pokémon 955/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/flittle
#   Successfully scraped: Flittle (Generation 9)
# --- Processing Pokémon 956/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/espathra
#   Successfully scraped: Espathra (Generation 9)
# --- Processing Pokémon 957/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/tinkatink
#   Successfully scraped: Tinkatink (Generation 9)
# --- Processing Pokémon 958/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/tinkatuff
#   Successfully scraped: Tinkatuff (Generation 9)
# --- Processing Pokémon 959/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/tinkaton
#   Successfully scraped: Tinkaton (Generation 9)
# --- Processing Pokémon 960/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/wiglett
#   Successfully scraped: Wiglett (Generation 9)
# --- Processing Pokémon 961/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/wugtrio
#   Successfully scraped: Wugtrio (Generation 9)
# --- Processing Pokémon 962/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/bombirdier
#   Successfully scraped: Bombirdier (Generation 9)
# --- Processing Pokémon 963/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/finizen
#   Successfully scraped: Finizen (Generation 9)
# --- Processing Pokémon 964/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/palafin
#   Successfully scraped: Palafin (Generation 9)
# --- Processing Pokémon 965/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/varoom
#   Successfully scraped: Varoom (Generation 9)
# --- Processing Pokémon 966/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/revavroom
#   Successfully scraped: Revavroom (Generation 9)
# --- Processing Pokémon 967/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/cyclizar
#   Successfully scraped: Cyclizar (Generation 9)
# --- Processing Pokémon 968/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/orthworm
#   Successfully scraped: Orthworm (Generation 9)
# --- Processing Pokémon 969/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/glimmet
#   Successfully scraped: Glimmet (Generation 9)
# --- Processing Pokémon 970/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/glimmora
#   Successfully scraped: Glimmora (Generation 9)
# --- Processing Pokémon 971/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/greavard
#   Successfully scraped: Greavard (Generation 9)
# --- Processing Pokémon 972/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/houndstone
#   Successfully scraped: Houndstone (Generation 9)
# --- Processing Pokémon 973/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/flamigo
#   Successfully scraped: Flamigo (Generation 9)
# --- Processing Pokémon 974/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/cetoddle
#   Successfully scraped: Cetoddle (Generation 9)
# --- Processing Pokémon 975/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/cetitan
#   Successfully scraped: Cetitan (Generation 9)
# --- Processing Pokémon 976/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/veluza
#   Successfully scraped: Veluza (Generation 9)
# --- Processing Pokémon 977/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/dondozo
#   Successfully scraped: Dondozo (Generation 9)
# --- Processing Pokémon 978/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/tatsugiri
#   Successfully scraped: Tatsugiri (Generation 9)
# --- Processing Pokémon 979/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/annihilape
#   Successfully scraped: Annihilape (Generation 9)
# --- Processing Pokémon 980/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/clodsire
#   Successfully scraped: Clodsire (Generation 9)
# --- Processing Pokémon 981/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/farigiraf
#   Successfully scraped: Farigiraf (Generation 9)
# --- Processing Pokémon 982/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/dudunsparce
#   Successfully scraped: Dudunsparce (Generation 9)
# --- Processing Pokémon 983/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/kingambit
#   Successfully scraped: Kingambit (Generation 9)
# --- Processing Pokémon 984/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/great-tusk
#   Successfully scraped: Great Tusk (Generation 9)
# --- Processing Pokémon 985/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/scream-tail
#   Successfully scraped: Scream Tail (Generation 9)
# --- Processing Pokémon 986/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/brute-bonnet
#   Successfully scraped: Brute Bonnet (Generation 9)
# --- Processing Pokémon 987/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/flutter-mane
#   Successfully scraped: Flutter Mane (Generation 9)
# --- Processing Pokémon 988/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/slither-wing
#   Successfully scraped: Slither Wing (Generation 9)
# --- Processing Pokémon 989/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/sandy-shocks
#   Successfully scraped: Sandy Shocks (Generation 9)
# --- Processing Pokémon 990/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/iron-treads
#   Successfully scraped: Iron Treads (Generation 9)
# --- Processing Pokémon 991/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/iron-bundle
#   Successfully scraped: Iron Bundle (Generation 9)
# --- Processing Pokémon 992/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/iron-hands
#   Successfully scraped: Iron Hands (Generation 9)
# --- Processing Pokémon 993/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/iron-jugulis
#   Successfully scraped: Iron Jugulis (Generation 9)
# --- Processing Pokémon 994/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/iron-moth
#   Successfully scraped: Iron Moth (Generation 9)
# --- Processing Pokémon 995/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/iron-thorns
#   Successfully scraped: Iron Thorns (Generation 9)
# --- Processing Pokémon 996/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/frigibax
#   Successfully scraped: Frigibax (Generation 9)
# --- Processing Pokémon 997/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/arctibax
#   Successfully scraped: Arctibax (Generation 9)
# --- Processing Pokémon 998/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/baxcalibur
#   Successfully scraped: Baxcalibur (Generation 9)
# --- Processing Pokémon 999/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/gimmighoul
#   Successfully scraped: Gimmighoul (Generation 9)
# --- Processing Pokémon 1000/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/gholdengo
#   Successfully scraped: Gholdengo (Generation 9)
# --- Processing Pokémon 1001/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/wo-chien
#   Successfully scraped: Wo-Chien (Generation 9)
# --- Processing Pokémon 1002/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/chien-pao
#   Successfully scraped: Chien-Pao (Generation 9)
# --- Processing Pokémon 1003/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/ting-lu
#   Successfully scraped: Ting-Lu (Generation 9)
# --- Processing Pokémon 1004/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/chi-yu
#   Successfully scraped: Chi-Yu (Generation 9)
# --- Processing Pokémon 1005/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/roaring-moon
#   Successfully scraped: Roaring Moon (Generation 9)
# --- Processing Pokémon 1006/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/iron-valiant
#   Successfully scraped: Iron Valiant (Generation 9)
# --- Processing Pokémon 1007/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/koraidon
#   Successfully scraped: Koraidon (Generation 9)
# --- Processing Pokémon 1008/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/miraidon
#   Successfully scraped: Miraidon (Generation 9)
# --- Processing Pokémon 1009/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/walking-wake
#   Successfully scraped: Walking Wake (Generation 9)
# --- Processing Pokémon 1010/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/iron-leaves
#   Successfully scraped: Iron Leaves (Generation 9)
# --- Processing Pokémon 1011/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/dipplin
#   Successfully scraped: Dipplin (Generation 9)
# --- Processing Pokémon 1012/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/poltchageist
#   Successfully scraped: Poltchageist (Generation 9)
# --- Processing Pokémon 1013/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/sinistcha
#   Successfully scraped: Sinistcha (Generation 9)
# --- Processing Pokémon 1014/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/okidogi
#   Successfully scraped: Okidogi (Generation 9)
# --- Processing Pokémon 1015/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/munkidori
#   Successfully scraped: Munkidori (Generation 9)
# --- Processing Pokémon 1016/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/fezandipiti
#   Successfully scraped: Fezandipiti (Generation 9)
# --- Processing Pokémon 1017/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/ogerpon
#   Successfully scraped: Ogerpon (Generation 9)
# --- Processing Pokémon 1018/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/archaludon
#   Successfully scraped: Archaludon (Generation 9)
# --- Processing Pokémon 1019/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/hydrapple
#   Successfully scraped: Hydrapple (Generation 9)
# --- Processing Pokémon 1020/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/gouging-fire
#   Successfully scraped: Gouging Fire (Generation 9)
# --- Processing Pokémon 1021/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/raging-bolt
#   Successfully scraped: Raging Bolt (Generation 9)
# --- Processing Pokémon 1022/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/iron-boulder
#   Successfully scraped: Iron Boulder (Generation 9)
# --- Processing Pokémon 1023/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/iron-crown
#   Successfully scraped: Iron Crown (Generation 9)
# --- Processing Pokémon 1024/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/terapagos
#   Successfully scraped: Terapagos (Generation 9)
# --- Processing Pokémon 1025/1025 ---
# Scraping Generation 9 detail page: https://pokemondb.net/pokedex/pecharunt
#   Successfully scraped: Pecharunt (Generation 9)
#
# --- SCRAPING COMPLETE ---
#
# Data for 1025 Pokémon saved to pokemon_pokedex_data_with_generations.csv
#
# First 5 entries from CSV (will be read back to verify):
#          name    generation          types  weight_kg  height_m abilities  \
# 0   Bulbasaur  Generation 1  Grass, Poison        6.9       0.7       NaN
# 1     Ivysaur  Generation 1  Grass, Poison       13.0       1.0       NaN
# 2    Venusaur  Generation 1  Grass, Poison      100.0       2.0       NaN
# 3  Charmander  Generation 1           Fire        8.5       0.6       NaN
# 4  Charmeleon  Generation 1           Fire       19.0       1.1       NaN
#
#   hidden_abilities    HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  \
# 0      1. Overgrow  45.0    49.0     49.0    65.0    65.0   45.0
# 1      1. Overgrow  60.0    62.0     63.0    80.0    80.0   60.0
# 2      1. Overgrow  80.0    82.0     83.0   100.0   100.0   80.0
# 3         1. Blaze  39.0    52.0     43.0    60.0    50.0   65.0
# 4         1. Blaze  58.0    64.0     58.0    80.0    65.0   80.0
#
#                                         url
# 0   https://pokemondb.net/pokedex/bulbasaur
# 1     https://pokemondb.net/pokedex/ivysaur
# 2    https://pokemondb.net/pokedex/venusaur
# 3  https://pokemondb.net/pokedex/charmander
# 4  https://pokemondb.net/pokedex/charmeleon
# 'generation' column IS in the saved CSV file.

# %% [markdown]
# ## Data visualisation / analysis (not needed for scrapping)

# %%
import pandas as pd

data = pd.read_csv('pokemon_pokedex_data_with_generations.csv')
print(data.head())
# Out:
#          name    generation          types  weight_kg  height_m abilities  \
# 0   Bulbasaur  Generation 1  Grass, Poison        6.9       0.7       NaN
# 1     Ivysaur  Generation 1  Grass, Poison       13.0       1.0       NaN
# 2    Venusaur  Generation 1  Grass, Poison      100.0       2.0       NaN
# 3  Charmander  Generation 1           Fire        8.5       0.6       NaN
# 4  Charmeleon  Generation 1           Fire       19.0       1.1       NaN
#
#   hidden_abilities    HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  \
# 0      1. Overgrow  45.0    49.0     49.0    65.0    65.0   45.0
# 1      1. Overgrow  60.0    62.0     63.0    80.0    80.0   60.0
# 2      1. Overgrow  80.0    82.0     83.0   100.0   100.0   80.0
# 3         1. Blaze  39.0    52.0     43.0    60.0    50.0   65.0
# 4         1. Blaze  58.0    64.0     58.0    80.0    65.0   80.0
#
#                                         url
# 0   https://pokemondb.net/pokedex/bulbasaur
# 1     https://pokemondb.net/pokedex/ivysaur
# 2    https://pokemondb.net/pokedex/venusaur
# 3  https://pokemondb.net/pokedex/charmander
# 4  https://pokemondb.net/pokedex/charmeleon

# %%
print('Weights:')
data['weight_kg'].describe()

# Find the name of the Pokémon with the highest weight
# Only keep the generation 1
data_generation = data[data['generation'] == 'Generation 3']
max_weight = data_generation['weight_kg'].max()
max_weight_pokemon = data_generation[data_generation['weight_kg'] == max_weight]['name'].values[0]
print(f"The Pokémon with the highest weight is: {max_weight_pokemon} with a weight of {max_weight} kg")

#print('Heights:')
#data['height_m'].describe()

max_height = data_generation['height_m'].max()
max_height_pokemon = data_generation[data_generation['height_m'] == max_height]['name'].values[0]
print(f"The Pokémon with the highest height is: {max_height_pokemon} with a height of {max_height} m")
# Out:
# Weights:
# The Pokémon with the highest weight is: Groudon with a weight of 950.0 kg
# The Pokémon with the highest height is: Wailord with a height of 14.5 m
